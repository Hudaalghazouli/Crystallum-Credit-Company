# %%
# import dependencies
import pandas as pd
import numpy as np
import copy, math
import matplotlib.pyplot as plt
from statistics import mean
from mpl_toolkits import mplot3d
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(precision=2)
import sqlite3

# %matplotlib inline

# %%
# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load in Dataset

# %%
# create dataframe from our csv file we are using for linear regression
creditCustomersCsv = pd.read_csv('Resources/BankChurners.csv')

# Create sqlite db
conn = sqlite3.connect('Resources/linear_then_logistic.db')
c = conn.cursor()

# Insert Records
creditCustomersCsv.to_sql('Customer', conn, if_exists='append', index = False)
# Out:
# 10127

# %%
# Delete Table (if need to re-create)
#c.execute('DROP TABLE IF EXISTS Customer')

# %%
# Load data into dataframe
creditCustomersDf = pd.read_sql('SELECT * FROM Customer', conn)
creditCustomersDf.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
# some rows have the value 'Unknown' in the income category & educatin level columns, filtering those out
filtered_df = creditCustomersDf[creditCustomersDf['Income_Category'].str.contains('Unknown')== False]
filtered_df = filtered_df[creditCustomersDf['Education_Level'].str.contains('Unknown')== False]

# %% [markdown]
# ### Below, we are testing the weight of education level and marital status on credit limit. We are changing values to numbers based on the below qualities.
#     - the higher your education the higher the number you get
#     - Married gets the highest benefit value, followed by single and so on (based on stability, we'd imagine a single person to be more stable than a divorced person)

# %%
# Change the values in the Income Category column to numerical values, we picked the value that fell between specified range
filtered_df.loc[filtered_df['Income_Category']== '$60K - $80K', 'Income_Category'] = 70000
filtered_df.loc[filtered_df['Income_Category']== 'Less than $40K', 'Income_Category'] = 20000
filtered_df.loc[filtered_df['Income_Category']== '$80K - $120K', 'Income_Category'] = 100000
filtered_df.loc[filtered_df['Income_Category']== '$40K - $60K', 'Income_Category'] = 50000
filtered_df.loc[filtered_df['Income_Category']== '$120K +', 'Income_Category'] = 120000

# %%
# change the value of education to numerical weights
filtered_df.loc[filtered_df['Education_Level']== 'High School', 'Education_Level'] = 0.50
filtered_df.loc[filtered_df['Education_Level']== 'Graduate', 'Education_Level'] = 0.70
filtered_df.loc[filtered_df['Education_Level']== 'Uneducated', 'Education_Level'] = 0.25
filtered_df.loc[filtered_df['Education_Level']== 'College', 'Education_Level'] = 0.60
filtered_df.loc[filtered_df['Education_Level']== 'Post-Graduate', 'Education_Level'] = 0.80
filtered_df.loc[filtered_df['Education_Level']== 'Doctorate', 'Education_Level'] = 0.90

# %%
#  Changing marital status to numerical weights
filtered_df.loc[filtered_df['Marital_Status']== 'Married', 'Marital_Status'] = 0.90
filtered_df.loc[filtered_df['Marital_Status']== 'Single', 'Marital_Status'] = 0.80
filtered_df.loc[filtered_df['Marital_Status']== 'Divorced', 'Marital_Status'] = 0.70
filtered_df.loc[filtered_df['Marital_Status']== 'Unknown', 'Marital_Status'] = 0.80

# %%
#  Changing gender to numerical weights
# It was noticed in Tableau that male customers had higher scores than female customers by a big margin
# filtered_df.loc[filtered_df['Gender']== 'M', 'Gender'] = 2.00
# filtered_df.loc[filtered_df['Gender']== 'F', 'Gender'] = 0.80

# %% [markdown]
# ## Find lowest credit limit and analyze similarities of customers that share that credit limit

# %%
# Create Dataframe to test out transformed features
newDF = filtered_df.copy()

# %%
newDF.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  7.641000e+03   7641.000000      7641.000000     7641.000000
# mean   7.392090e+08     46.303756         2.351525       35.950530
# std    3.693693e+07      7.958827         1.290410        7.941765
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130198e+08     41.000000         1.000000       31.000000
# 50%    7.178958e+08     46.000000         2.000000       36.000000
# 75%    7.732890e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               7641.000000             7641.000000
# mean                   3.814553                2.343411
# std                    1.550470                0.999927
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# Below is an engineered feature

# The idea is a higher income should benefit you, so your income is multiplied by a composite score which is created by (Months_on_book * Education_Level * Marital_Status) and divided by
# a created weight (Dependent_count + Avg_Utilization_Ratio)

# My thinking is you want your composite score(Months_on_book * Education_Level * Marital_Status) to be a high number
# you want the weight (Dependent_count + Avg_Utilization_Ratio) to be a low number 
# So you would want the weight to either make the composite score bigger or at least not drag it down so when you multiply by the income you get a higher score

# With the overall idea being a higher score would be a higher credit limit

newDF['Transformed'] = ( newDF['Income_Category'] * ( (newDF['Months_on_book']* newDF['Education_Level'] * newDF['Marital_Status'])
                                                     / ( (1 + newDF['Dependent_count']) + (1+newDF['Avg_Utilization_Ratio']) ) ) )/1000

# %% [markdown]
# ### Find lowest credit limit

# %%
# lowest credit limit 
newDF['Credit_Limit'].min()
# Out:
# 1438.3

# %% [markdown]
# ### Find highest credit limit

# %%
# highest credit limit 
newDF['Credit_Limit'].max()
# Out:
# 34516.0

# %%
# Customers with lower credit limits, 8559.18 is the average credit limit for all customers
lowCredLimit = newDF.loc[(newDF['Credit_Limit'] >= 1438.3) & (newDF['Credit_Limit'] < 8559.18)]
lowCredLimit.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 1             0.7            0.8           20000          Blue
# 2             0.7            0.9          100000          Blue
# 3             0.5            0.8           20000          Blue
# 4            0.25            0.9           70000          Blue
# 5             0.7            0.9           50000          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 1              44                         6                       1
# ...

# %%
# Customers with higher credit limits
highCredLimit = newDF.loc[(newDF['Credit_Limit'] > 8559.18) & (newDF['Credit_Limit'] <= 34516)]
highCredLimit.head()
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer            45      M                3
# 7   818906208  Existing Customer            32      M                0
# 8   710930508  Existing Customer            37      M                3
# 9   719661558  Existing Customer            48      M                2
# 12  710599683  Existing Customer            56      M                1
#
#    Education_Level Marital_Status Income_Category Card_Category  \
# 0              0.5            0.9           70000          Blue
# 7              0.5            0.8           70000        Silver
# 8             0.25            0.8           70000          Blue
# 9              0.7            0.8          100000          Blue
# 12             0.6            0.8          100000          Blue
#
#     Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0               39                         5                       1
# ...

# %% [markdown]
# ## Display quick statistical analysis of both low credit limits, and high credit limits to compare

# %%
lowCredLimit.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  5.272000e+03   5272.000000      5272.000000     5272.000000
# mean   7.390743e+08     46.226100         2.300455       35.873103
# std    3.679845e+07      8.311002         1.309603        8.201620
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130838e+08     40.000000         1.000000       31.000000
# 50%    7.178581e+08     46.000000         2.000000       36.000000
# 75%    7.726907e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               5272.000000             5272.000000
# mean                   3.877845                2.354894
# std                    1.527422                1.010192
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
highCredLimit.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  2.369000e+03   2369.000000      2369.000000     2369.000000
# mean   7.395087e+08     46.476572         2.465175       36.122837
# std    3.724932e+07      7.111413         1.239377        7.329229
# min    7.081036e+08     26.000000         0.000000       13.000000
# 25%    7.128632e+08     42.000000         2.000000       32.000000
# 50%    7.180026e+08     46.000000         3.000000       36.000000
# 75%    7.783463e+08     51.000000         3.000000       40.000000
# max    8.282919e+08     65.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               2369.000000             2369.000000
# mean                   3.673702                2.317856
# std                    1.591889                0.976423
# min                    1.000000                0.000000
# 25%                    2.000000                2.000000
# ...

# %% [markdown]
# ## Visualize Data
# - Plot out different features to gauge predictability

# %%
# create a list of Avg_Utilization_Ratio to plot
avg_Util_ratio = newDF['Avg_Utilization_Ratio']

# %%
# create a list of Credit_Limit & Income_Category to plot
creditLimit = newDF['Credit_Limit']
income = newDF['Income_Category']

# %%
figure1, figure1_axes = plt.subplots()
figure1_axes.plot(creditLimit, avg_Util_ratio, 'go',)
figure1_axes.set_xlabel('Credit Limit')
figure1_axes.set_ylabel('Avg Utilization Ratio')
figure1_axes.set_title('Predicting Utilization with Credit Limit');

# %% [markdown]
# We notice that income is not a good feature for predicting credit limit, however credit limit looks to be pretty good at predicting credit utilization

# %%
figure1, figure1_axes = plt.subplots()
figure1_axes.plot(income, creditLimit, 'go',)
figure1_axes.set_xlabel('Our Score')
figure1_axes.set_ylabel('Credit Limit')
figure1_axes.set_title('Predicting Credit Limit with Income');

# %% [markdown]
# ### For the below visualization,
# - My hopes were that, when plotting Our Score vs Credit Limit, the data would have a slope that is tilting to the right which would indicate higer scores in gernal mean higher credit limit. Which it kind of does. It's not perfect but you can see it's trying to work

# %%
# create a list for our score (engineered feature)
ourScore = newDF['Transformed']

# %%
figure1, figure1_axes = plt.subplots()
figure1_axes.plot(ourScore, creditLimit, 'go',)
figure1_axes.set_xlabel('Our Score')
figure1_axes.set_ylabel('Credit Limit')
figure1_axes.set_title('Predicting Credit Limit with Our Score');

# %% [markdown]
# ### Picking our features
# - Customer age = index (2)
# - Gender = index (3)
# - Dependent count = index (4)
# - Edu level = index (5)
# - Marital status = index (6)
# - Income = index (7)
# - Months on book = index (9)
# - Total relationship count = index (10)
# - Cred limit = index (13)
# - Total revolving balance = index (14)
# - Total trans amnt = index (17)
# - Util ratio = index (20)
# - Our ceated score = index (23)

# %%
# create empty list
features = []
targets = []

# for loop to create feature lists to add to above created list

for i in range(len(newDF)):
    feature_gatherer = []
    credLimitY = ''
    
    credLimitY = newDF.iloc[i,13]
    # feature.append(newDF.iloc[i,2])
    # feature.append(newDF.iloc[i,3])
    feature_gatherer.append(newDF.iloc[i,4])
    feature_gatherer.append(newDF.iloc[i,5])
    feature_gatherer.append(newDF.iloc[i,6])
    feature_gatherer.append(newDF.iloc[i,7])
    # feature.append(newDF.iloc[i,9])
    # feature.append(newDF.iloc[i,10])
    feature_gatherer.append(newDF.iloc[i,14])
    feature_gatherer.append(newDF.iloc[i,17]) 
    feature_gatherer.append(newDF.iloc[i,20])
    feature_gatherer.append(newDF.iloc[i,23])

    
    features.append(feature_gatherer)
    targets.append(credLimitY)
    
print(features[:5])
print(targets[:5])
# Out:
# [[3, 0.5, 0.9, 70000, 777, 1144, 0.061, 242.73858921161826], [5, 0.7, 0.8, 20000, 864, 1291, 0.105, 69.35960591133005], [3, 0.7, 0.9, 100000, 0, 1887, 0.0, 453.59999999999997], [4, 0.5, 0.8, 20000, 2517, 1171, 0.76, 40.23668639053255], [3, 0.25, 0.9, 70000, 0, 816, 0.0, 66.15]]
# [12691.0, 8256.0, 3418.0, 3313.0, 4716.0]

# %% [markdown]
# ## Training Model for all data

# %%
# Turn features and targets lists into numpy arrays
x_features = np.array(features)
y_targets = np.array(targets)

# %%
# Split the data into X_train, X_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(x_features, y_targets)

# %% [markdown]
# ### skLearn section 1st trial

# %%
# create model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(x_train)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(x_train,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(y_train,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[5.00e+00 6.50e-01 2.00e-01 1.00e+05 2.52e+03 1.75e+04 9.99e-01 1.84e+03]
# Peak to Peak range by column in Normalized X:33077.7

# %%
sgdr = SGDRegressor(max_iter=100000)
sgdr.fit(X_norm, y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")
# Out:
# SGDRegressor(max_iter=100000)
# number of iterations completed: 9, number of weight updates: 51571.0

# %%
b_norm = sgdr.intercept_
w_norm = sgdr.coef_
print(f"model parameters:                   w: {w_norm}, b:{b_norm}")
# Out:
# model parameters:                   w: [  308.47  -126.13  -334.87  3139.8   3541.32   860.28 -5397.75   298.56], b:[8672.47]

# %%
# make a prediction using sgdr.predict()
y_pred_sgd = sgdr.predict(X_norm)
# make a prediction using w,b. 
y_pred = np.dot(X_norm, w_norm) + b_norm  
print(f"prediction using np.dot() and sgdr.predict match: {(y_pred == y_pred_sgd).all()}")

print(f"Prediction on training set:\n{y_pred[:20]}" )
print(f"Target values \n{y_train[:20]}")
# Out:
# prediction using np.dot() and sgdr.predict match: True
# Prediction on training set:
# [21721.33  5432.71  3619.47  6604.87 15460.43  5217.97   392.14 16083.9
#  18436.09  8262.11 13682.41 -2800.59  6872.88 14111.87  7953.8   6874.58
#   2233.27  9396.96  5712.97  8043.92]
# Target values
# [34516.  13626.   3172.   2492.  23355.   3257.   1573.  33122.  21615.
#   1438.3  9357.   2178.   6458.   9074.   4373.   6236.   2142.   3786.
#   1916.   3680. ]

# %%
# Use our model to make predictions
predicted = model.predict(x_test)

# Score the predictions with r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(mse)
print(f"R-squared (R2): {r2}")
# Out:
# 40793343.87720766
# R-squared (R2): 0.5135971174362641

# %%
# Display score
model.score(x_test, y_test)
# Out:
# 0.5135971174362641

# %% [markdown]
# ## Manual Gradient Descent and Predict functions section 2nd trial

# %%
# --------------------------------------------- Section for testing manual gradient descent -----------------------------------------------------

# %%
# Print features and targets from above    
print(features[:5])
print(targets[:5])
# Out:
# [[3, 0.5, 0.9, 70000, 777, 1144, 0.061, 242.73858921161826], [5, 0.7, 0.8, 20000, 864, 1291, 0.105, 69.35960591133005], [3, 0.7, 0.9, 100000, 0, 1887, 0.0, 453.59999999999997], [4, 0.5, 0.8, 20000, 2517, 1171, 0.76, 40.23668639053255], [3, 0.25, 0.9, 70000, 0, 816, 0.0, 66.15]]
# [12691.0, 8256.0, 3418.0, 3313.0, 4716.0]

# %%
# visualize data

X_train = np.array(features)
y_train = np.array(targets)

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(X_train)
X_norm.shape
# Out:
# (7641, 8)

# %%
# data is stored in numpy array/matrix
print(f"X Shape: {X_norm.shape}, X Type:{type(X_norm)})")
print(X_train)
print(f"y Shape: {y_train.shape}, y Type:{type(y_train)})")
print(y_train)
# Out:
# X Shape: (7641, 8), X Type:<class 'numpy.ndarray'>)
# [[3.00e+00 5.00e-01 9.00e-01 ... 1.14e+03 6.10e-02 2.43e+02]
#  [5.00e+00 7.00e-01 8.00e-01 ... 1.29e+03 1.05e-01 6.94e+01]
#  [3.00e+00 7.00e-01 9.00e-01 ... 1.89e+03 0.00e+00 4.54e+02]
#  ...
#  [1.00e+00 5.00e-01 9.00e-01 ... 1.03e+04 0.00e+00 1.08e+02]
#  [2.00e+00 7.00e-01 8.00e-01 ... 8.40e+03 0.00e+00 2.52e+02]
#  [2.00e+00 7.00e-01 9.00e-01 ... 1.03e+04 1.89e-01 7.52e+01]]
# y Shape: (7641,), y Type:<class 'numpy.ndarray'>)
# [12691.  8256.  3418. ...  5409.  5281. 10388.]

# %%
# w and b values found by sklearn trial above

# b_init = 8561.07
# w_init = np.array([286.61, -154.2 , -475.49, 3517.54, 3529.85, 686.09, -5455.72, 221.83])
# print(f"w_init shape: {w_init.shape}, b_init type: {type(b_init)}")

# %%
b_init = 1000
w_init = np.array([100, 100, 100, 100, 100, 100, 100, 100])
print(f"w_init shape: {w_init.shape}, b_init type: {type(b_init)}")
# Out:
# w_init shape: (8,), b_init type: <class 'int'>

# %%
def predict(x, w, b): 
    """
    single predict using linear regression
    Args:
      x (ndarray): Shape (n,) example with multiple features
      w (ndarray): Shape (n,) model parameters   
      b (scalar):             model parameter 
      
    Returns:
      p (scalar):  prediction
    """
    p = np.dot(x, w) + b     
    return p

# %%
# get a row from our training data
x_vec = X_norm[0,:]
print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# make a prediction
f_wb = predict(x_vec,w_init, b_init)
print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")
# Out:
# x_vec shape (8,), x_vec value: [ 0.5  -0.44  0.98  0.42 -0.48 -0.95 -0.79  0.05]
# f_wb shape (), prediction: 929.2972218681464

# %%
def compute_cost(X, y, w, b): 
    """
    compute cost
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
    Returns:
      cost (scalar): cost
    """
    m = X.shape[0]
    cost = 0.0
    for i in range(m):                                
        f_wb_i = np.dot(X[i], w) + b           #(n,)(n,) = scalar (see np.dot)
        cost = cost + (f_wb_i - y[i])**2       #scalar
    cost = cost / (2 * m)                      #scalar    
    return cost

# %%
# Compute and display cost using our pre-chosen optimal parameters. 
cost = compute_cost(X_norm, y_train, w_init, b_init)
print(f'Cost at optimal w : {cost}')
# Out:
# Cost at optimal w : 69916750.63710259

# %%
# OLD DONT RUN
# Cost at optimal w : 41745790.73400999

# %%
print(X_train.shape)
m,n = X_train.shape 
print(np.zeros((n,)))
# Out:
# (7641, 8)
# [0. 0. 0. 0. 0. 0. 0. 0.]

# %%
def compute_gradient(X, y, w, b): 
    """
    Computes the gradient for linear regression 
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
    Returns:
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w. 
      dj_db (scalar):       The gradient of the cost w.r.t. the parameter b. 
    """
    m,n = X.shape           #(number of examples, number of features)
    dj_dw = np.zeros((n,))
    dj_db = 0.

    for i in range(m):                             
        err = (np.dot(X[i], w) + b) - y[i]   
        for j in range(n):                         
            dj_dw[j] = dj_dw[j] + err * X[i, j]    
        dj_db = dj_db + err                        
    dj_dw = dj_dw / m                                
    dj_db = dj_db / m                                
        
    return dj_db, dj_dw

# %%
#Compute and display gradient 
tmp_dj_db, tmp_dj_dw = compute_gradient(X_norm, y_train, w_init, b_init)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: \n {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: -7559.183209004101
# dj_dw at initial w,b:
#  [ -603.99   269.98   587.59 -5295.65  -124.59 -1478.93  4538.06 -3613.47]

# %%
def gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters): 
    """
    Performs batch gradient descent to learn theta. Updates theta by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (m,n))   : Data, m examples with n features
      y (ndarray (m,))    : target values
      w_in (ndarray (n,)) : initial model parameters  
      b_in (scalar)       : initial model parameter
      cost_function       : function to compute cost
      gradient_function   : function to compute the gradient
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent
      
    Returns:
      w (ndarray (n,)) : Updated values of parameters 
      b (scalar)       : Updated value of parameter 
      """
    
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    b = b_in
    
    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_db,dj_dw = gradient_function(X, y, w, b)   ##None

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw               ##None
        b = b - alpha * dj_db               ##None
      
        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            J_history.append( cost_function(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]:8.2f}   ")
        
    return w, b, J_history #return final w,b and J history for graphing

# %% [markdown]
# ## Initialize gradient descent with a learning rate of 0.0001

# %%
# initialize parameters
initial_w = np.array([100, 100 , 100, 100, 100, 100, 100, 100])
initial_b = 1000

# create empty list to store predicted credit limits
predList = []

# some gradient descent settings
iterations = 10000
alpha = 0.0001
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_norm, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = X_train.shape
for i in range(m):
    pred = np.dot(X_norm[i], w_final) + b_final
    predList.append(pred)
# Out:
# Iteration    0: Cost 69904569.30
# Iteration 1000: Cost 59279180.19
# Iteration 2000: Cost 51189089.39
# Iteration 3000: Cost 44965513.22
# Iteration 4000: Cost 40130871.73
# Iteration 5000: Cost 36340774.84
# Iteration 6000: Cost 33344326.01
# Iteration 7000: Cost 30956814.71
# Iteration 8000: Cost 29040816.57
# Iteration 9000: Cost 27493021.69
# b,w found by gradient descent: 5778.45,[  562.55  -270.18  -303.97  2619.77   787.97   899.97 -2304.5   1451.31]

# %% [markdown]
# #### Lowest cost achieved by gradient descent was 27493021.69 and b,w found by gradient descent: 5778.45,[  562.55  -270.18  -303.97  2619.77   787.97   899.97 -2304.5   1451.31]
#
# #### Visualize cost vs iterations below

# %%
x = J_hist[::1000]

costFigure, costFigure_axes = plt.subplots()
costFigure_axes.plot(x)
costFigure_axes.set_xlabel('Every 1000th iteration')
costFigure_axes.set_ylabel('Cost')
costFigure_axes.set_title('Alpha = 0.0001 10000 Iterations Cost Function');
costFigure.savefig("Output_Data/visualizations/0001Alpha10000Iterations.png")

plt.show()

# %% [markdown]
# ## Initialize gradient descent with a learning rate of 0.001

# %%
# initialize parameters
initial_w = np.array([100, 100 , 100, 100, 100, 100, 100, 100])
initial_b = 1000

# create empty list to store predicted credit limits
predList = []

# some gradient descent settings
iterations = 10000
alpha = 0.001
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_norm, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = X_train.shape
for i in range(m):
    pred = np.dot(X_norm[i], w_final) + b_final
    predList.append(pred)
# Out:
# Iteration    0: Cost 69795014.83
# Iteration 1000: Cost 26219646.87
# Iteration 2000: Cost 21096415.12
# Iteration 3000: Cost 20006123.32
# Iteration 4000: Cost 19606629.52
# Iteration 5000: Cost 19403872.47
# Iteration 6000: Cost 19288865.41
# Iteration 7000: Cost 19221564.55
# Iteration 8000: Cost 19181740.24
# Iteration 9000: Cost 19158001.00
# b,w found by gradient descent: 8558.84,[  434.94  -226.5   -450.05  3206.07  3349.66   835.94 -5154.07   511.77]

# %% [markdown]
# #### Lowest cost achieved by gradient descent was 19158001.00 and b,w found by gradient descent: 8558.84,[  434.94  -226.5   -450.05  3206.07  3349.66   835.94 -5154.07   511.77]

# %%
x = J_hist[::1000]

costFigure, costFigure_axes = plt.subplots()
costFigure_axes.plot(x)
costFigure_axes.set_xlabel('Every 1000th iteration')
costFigure_axes.set_ylabel('Cost')
costFigure_axes.set_title('Alpha = 0.001 10000 Iterations Cost Function');
costFigure.savefig("Output_Data/visualizations/001Alpha10000Iterations.png")

plt.show()

# %% [markdown]
# ## Initialize gradient descent with a learning rate of 0.01

# %%
# initialize parameters
initial_w = np.array([100, 100 , 100, 100, 100, 100, 100, 100])
initial_b = 1000

# create empty list to store predicted credit limits
predList = []

# some gradient descent settings
iterations = 10000
alpha = 0.01
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_norm, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iterations)

print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")

m,_ = X_train.shape
for i in range(m):
    pred = np.dot(X_norm[i], w_final) + b_final
    predList.append(pred)
    # print(f"prediction: {pred}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost 68707150.91
# Iteration 1000: Cost 19143521.02
# Iteration 2000: Cost 19120910.75
# Iteration 3000: Cost 19120472.05
# Iteration 4000: Cost 19120449.51
# Iteration 5000: Cost 19120448.17
# Iteration 6000: Cost 19120448.09
# Iteration 7000: Cost 19120448.08
# Iteration 8000: Cost 19120448.08
# Iteration 9000: Cost 19120448.08
# b,w found by gradient descent: 8559.18,[  313.04  -109.93  -420.94  3323.99  3554.1    791.   -5391.64   242.  ]

# %% [markdown]
# #### Lowest cost achieved by gradient descent was 19120448.08 and b,w found by gradient descent: 8559.18,[  313.04  -109.93  -420.94  3323.99  3554.1    791.   -5391.64   242.  ]

# %%
x = J_hist[::1000]

costFigure, costFigure_axes = plt.subplots()
costFigure_axes.plot(x)
costFigure_axes.set_xlabel('Every 1000th iteration')
costFigure_axes.set_ylabel('Cost')
costFigure_axes.set_title('Alpha = 0.01 10000 Iterations Cost Function');
costFigure.savefig("Output_Data/visualizations/01Alpha10000Iterations.png")

plt.show()

# %% [markdown]
# ## Initialize gradient descent with a learning rate of 0.1

# %%
# initialize parameters
initial_w = np.array([100, 100 , 100, 100, 100, 100, 100, 100])
initial_b = 1000

# create empty list to store predicted credit limits
predList = []

# some gradient descent settings
iterations = 10000
alpha = 0.1
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_norm, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")

m,_ = X_train.shape
for i in range(m):
    pred = np.dot(X_norm[i], w_final) + b_final
    predList.append(pred)
    # print(f"prediction: {pred}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost 58596591.93
# Iteration 1000: Cost 19120448.08
# Iteration 2000: Cost 19120448.08
# Iteration 3000: Cost 19120448.08
# Iteration 4000: Cost 19120448.08
# Iteration 5000: Cost 19120448.08
# Iteration 6000: Cost 19120448.08
# Iteration 7000: Cost 19120448.08
# Iteration 8000: Cost 19120448.08
# Iteration 9000: Cost 19120448.08
# b,w found by gradient descent: 8559.18,[  313.04  -109.93  -420.94  3323.99  3554.1    791.   -5391.64   242.  ]

# %% [markdown]
# #### Lowest cost achieved by gradient descent was 19120448.08 and b,w found by gradient descent: 8559.18,[  313.04  -109.93  -420.94  3323.99  3554.1    791.   -5391.64   242.  ]

# %%
x = J_hist[::1000]

costFigure, costFigure_axes = plt.subplots()
costFigure_axes.plot(x)
costFigure_axes.set_xlabel('Every 1000th iteration')
costFigure_axes.set_ylabel('Cost')
costFigure_axes.set_title('Alpha = 0.1 10000 Iterations Cost Function');
costFigure.savefig("Output_Data/visualizations/1Alpha10000Iterations.png")

plt.show()

# %% [markdown]
# ### Store used features and predictions in data frame then visualize difference

# %%
# reminder that predicted credit limits are stored in the predList variable

# %%
# Create new data frame for prediction results

dependentCount = [i[0] for i in X_norm[::]]
eduLevel = [i[1] for i in X_norm[::]]
maritalStatus = [i[2] for i in X_norm[::]]
income = [i[3] for i in X_norm[::]]
trb = [i[4] for i in X_norm[::]]
tta = [i[5] for i in X_norm[::]]
aur = [i[6] for i in X_norm[::]]
our_Score = [i[7] for i in X_norm[::]]


data ={ 
    "Dependent count": dependentCount,
    "Education Level": eduLevel,
    "Marital Status": maritalStatus,
    "Income": income,
    "Total Revolving Balance": trb,
    "Total Transaction Amount": tta,
    "Average Utilization Ratio": aur,
    "Our_Score": our_Score,
    "Target Credit Limit": y_train,
    "prediction": predList}

df = pd.DataFrame(data)
df.to_csv('Output_Data/prediction_results.csv')

df
# Out:
#       Dependent count  Education Level  Marital Status    Income  \
# 0            0.502567        -0.441744        0.977072  0.417710
# 1            2.052564         0.651846       -0.629860 -1.022078
# 2            0.502567         0.651846        0.977072  1.281582
# 3            1.277566        -0.441744       -0.629860 -1.022078
# 4            0.502567        -1.808732        0.977072  0.417710
# ...               ...              ...             ...       ...
# 7636        -1.047429         0.651846       -0.629860 -1.022078
# 7637        -0.272431         0.651846       -0.629860 -0.158205
# 7638        -1.047429        -0.441744        0.977072 -1.022078
# 7639        -0.272431         0.651846       -0.629860 -0.158205
# 7640        -0.272431         0.651846        0.977072 -1.022078
#
#       Total Revolving Balance  Total Transaction Amount  \
# 0                   -0.478491                 -0.946333
# 1                   -0.371510                 -0.903810
# ...

# %%
corr_matrix = np.corrcoef(y_train, predList)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)
# Out:
# 0.5443993657779997

# %% [markdown]
# The above cost function shows the humongous cost does descrease

# %%
# --------------------------------------------- End Section for testing manual gradient descent -----------------------------------------------------

# %% [markdown]
# ## Third trial testing for better skLearn results using label enconder

# %%
trial3_DF = creditCustomersDf.copy()
trial3_DF.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
                'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],inplace=True, axis=1)
trial3_DF.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
# use label encoder on non-numberical columns so they can be used as features
le_Gender = LabelEncoder()
le_Education_Level = LabelEncoder()
le_Marital_Status = LabelEncoder()
le_Income_Category = LabelEncoder()

trial3_DF['Gender_n'] = le_Gender.fit_transform(trial3_DF['Gender'])
trial3_DF['Education_n'] = le_Education_Level.fit_transform(trial3_DF['Education_Level'])
trial3_DF['Marital_n'] = le_Education_Level.fit_transform(trial3_DF['Marital_Status'])
trial3_DF['Income_n'] = le_Income_Category.fit_transform(trial3_DF['Income_Category'])

# %%
trial3_DF.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %% [markdown]
# ### Picking our features
# - Customer age = index (2)
# - Gender = index (3)
# - Dependent count = index (4)
# - Edu level = index (5)
# - Marital status = index (6)
# - Income = index (7)
# - Months on book = index (9)
# - Total relationship count = index (10)
# - Cred limit = index (13)
# - Total revolving balance = index (14)
# - Total trans amnt = index (17)
# - Util ratio = index (20)
# - Gender_n = index (21)
# - Education_n = index (22)
# - Marital_n = index (23)
# - Income_n =  index(24)

# %%
# create empty list
features = []
targets = []

# for loop to create feature lists to add to above created list

for i in range(len(trial3_DF)):
    feature = []
    credLimitY = ''
    
    credLimitY = trial3_DF.iloc[i,13]
    # feature.append(newDF.iloc[i,2])
    # feature.append(newDF.iloc[i,3])
    feature.append(trial3_DF.iloc[i,4])
    feature.append(trial3_DF.iloc[i,22])
    feature.append(trial3_DF.iloc[i,23])
    feature.append(trial3_DF.iloc[i,24])
    # feature.append(newDF.iloc[i,9])
    # feature.append(newDF.iloc[i,10])
    feature.append(trial3_DF.iloc[i,14])
    feature.append(trial3_DF.iloc[i,17]) 
    feature.append(trial3_DF.iloc[i,20])
    # feature.append(newDF.iloc[i,23])

    
    features.append(feature)
    targets.append(credLimitY)
    
print(features[:5])
print(targets[:5])
# Out:
# [[3, 3, 1, 2, 777, 1144, 0.061], [5, 2, 2, 4, 864, 1291, 0.105], [3, 2, 1, 3, 0, 1887, 0.0], [4, 3, 3, 4, 2517, 1171, 0.76], [3, 5, 1, 2, 0, 816, 0.0]]
# [12691.0, 8256.0, 3418.0, 3313.0, 4716.0]

# %% [markdown]
# ### Training Model for all data

# %%
# Turn features and targets lists into numpy arrays
x_features = np.array(features)
y_targets = np.array(targets)

# %%
# Split the data into X_train, X_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(x_features, y_targets)

# %%
# create model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(x_train)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(x_features,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(y_targets,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[5.00e+00 6.00e+00 3.00e+00 5.00e+00 2.52e+03 1.80e+04 9.99e-01]
# Peak to Peak range by column in Normalized X:33077.7

# %%
sgdr = SGDRegressor(max_iter=100000)
sgdr.fit(X_norm, y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")
# Out:
# SGDRegressor(max_iter=100000)
# number of iterations completed: 9, number of weight updates: 68356.0

# %%
b_norm = sgdr.intercept_
w_norm = sgdr.coef_
print(f"model parameters:                   w: {w_norm}, b:{b_norm}")
# Out:
# model parameters:                   w: [  274.82    79.87   -10.24  -980.41  4871.51   701.77 -7040.34], b:[8609.07]

# %%
# make a prediction using sgdr.predict()
y_pred_sgd = sgdr.predict(X_norm)
# make a prediction using w,b. 
y_pred = np.dot(X_norm, w_norm) + b_norm  
print(f"prediction using np.dot() and sgdr.predict match: {(y_pred == y_pred_sgd).all()}")

print(f"Prediction on training set:\n{y_pred[:20]}" )
print(f"Target values \n{y_train[:20]}")
# Out:
# prediction using np.dot() and sgdr.predict match: True
# Prediction on training set:
# [-3208.36  4662.81 11265.89  1198.95 14486.2   7384.36  8920.97  3546.03
#  12983.8   2440.38 -3640.5  12235.2   6921.95  7884.   18819.37 17587.1
#  16925.89 19808.46  1193.26  7782.45]
# Target values
# [ 1686.   3111.  11638.   2162.   7049.   4256.  14575.   3512.   7477.
#   2545.   1629.   8997.   3443.   1438.3 13114.  34516.  34516.  19846.
#   1923.   4026. ]

# %%
# Use our model to make predictions
predicted = model.predict(x_test)

# Score the predictions with r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(mse)
print(f"R-squared (R2): {r2}")
# Out:
# 48880313.33371608
# R-squared (R2): 0.44337258714522076

# %%
# Display score
model.score(x_test, y_test)
# Out:
# 0.44337258714522076

# %% [markdown]
# ## Fourth trial creating credit limit ranges

# %%
creditCustomersDf['Credit_Limit'].max()
# Out:
# 34516.0

# %%
creditCustomersDf['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
creditCustomersDf['Credit_Limit'].max()
# Out:
# 34516.0

# %%
creditCustomersDf['Credit_Limit'].min()
# Out:
# 1438.3

# %%
creditCustomersDf
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df = creditCustomersDf.copy()

# %%
df['Credit_Limit']=df['Credit_Limit'].astype(float)

# %%
def new_CreditLimit(sample):
    if sample >= 4549.0:
        return 1
    else:
        return 0

# %%
df['Credit_Limit'] = df['Credit_Limit'].apply(new_CreditLimit)

# %%
df['Credit_Limit'].value_counts()
# Out:
# 1    5066
# 0    5061
# Name: Credit_Limit, dtype: int64

# %%
X_dummies = pd.get_dummies(df)
print(X_dummies.columns)
X_dummies
# Out:
# Index(['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',
#        'Attrition_Flag_Attrited Customer', 'Attrition_Flag_Existing Customer',
#        'Gender_F', 'Gender_M', 'Education_Level_College',
#        'Education_Level_Doctorate', 'Education_Level_Graduate',
#        'Education_Level_High School', 'Education_Level_Post-Graduate',
#        'Education_Level_Uneducated', 'Education_Level_Unknown',
# ...

# %%
X = X_dummies.drop('Credit_Limit', axis=1)
y = X_dummies['Credit_Limit']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
clf = RandomForestClassifier(random_state=42, n_estimators=1000)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=42)

# %%
print(f"Training Data Score random forests classifier: {clf.score(X_train, y_train)}")
print(f"Testing Data Score random forests classifier: {clf.score(X_test, y_test)}")
# Out:
# Training Data Score random forests classifier: 1.0
# Testing Data Score random forests classifier: 0.9877567140600316

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
confusion_matrix(y_true, y_pred)
# Out:
# array([[1295,   10],
#        [  21, 1206]])

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])
